# %% [markdown]
# **复习**:这门课程得主要目的是通过真实的数据，以实战的方式了解数据分析的流程和熟悉数据分析python的基本操作。知道了课程的目的之后，我们接下来我们要正式的开始数据分析的实战教学，完成kaggle上[泰坦尼克的任务](https://www.kaggle.com/c/titanic/overview)，实战数据分析全流程。
# 这里有两份资料：
# 教材《Python for Data Analysis》和 baidu.com &
# google.com（善用搜索引擎）

# %% [markdown]
# ## 1 第一章：数据载入及初步观察

# %% [markdown]
# ### 1.1 载入数据
# 数据集下载 https://www.kaggle.com/c/titanic/overview

# %% [markdown]
# #### 1.1.1 任务一：导入numpy和pandas

# %%
#写入代码
import numpy as np
import pandas as pd
import os

# %% [markdown]
# 【提示】如果加载失败，学会如何在你的python环境下安装numpy和pandas这两个库

# %% [markdown]
# #### 1.1.2 任务二：载入数据
# (1) 使用相对路径载入数据
# (2) 使用绝对路径载入数据

# %%
#写入代码
adata = pd.read_csv(r'C:\python3.7\hands-on-data-analysis-master\第一单元项目集合\test_1.csv') # 绝对路径
print(adata)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#写入代码
os.getcwd()
adata = pd.read_csv(r'test_1.csv') # 相对路径 与程序在一个文件夹底下的数据
print(adata)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# 【提示】相对路径载入报错时，尝试使用os.getcwd()查看当前工作目录。
# 【思考】知道数据加载的方法后，试试pd.read_csv()和pd.read_table()的不同，如果想让他们效果一样，需要怎么做？了解一下'.tsv'和'.csv'的不同，如何加载这两个数据集？
# 【总结】加载的数据是所有工作的第一步，我们的工作会接触到不同的数据格式（eg:.csv;.tsv;.xlsx）,但是加载的方法和思路都是一样的，在以后工作和做项目的过程中，遇到之前没有碰到的问题，要多多查资料吗，使用googel，了解业务逻辑，明白输入和输出是什么。

# %% [markdown]
# #### 1.1.3 任务三：每1000行为一个数据模块，逐块读取

# %%
#写入代码
chunker = pd.read_csv(r'test_1.csv', chunksize=100)
for piece in chunker:
    print('--------value counts start----------')
    print(piece)
    print('--------value counts end----------')
# Out:
# --------value counts start----------
#     Unnamed: 0  PassengerId  Survived  Pclass  \
# 0            0            1         0       3
# 1            1            2         1       1
# 2            2            3         1       3
# 3            3            4         1       1
# 4            4            5         0       3
# ..         ...          ...       ...     ...
# 95          95           96         0       3
# 96          96           97         0       1
# 97          97           98         1       1
# 98          98           99         1       2
# 99          99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...

# %% [markdown]
# 【思考】什么是逐块读取？为什么要逐块读取呢？
#
# 【提示】大家可以chunker(数据块)是什么类型？用`for`循环打印出来出处具体的样子是什么？

# %% [markdown]
# #### 1.1.4 任务四：将表头改成中文，索引改为乘客ID [对于某些英文资料，我们可以通过翻译来更直观的熟悉我们的数据]
# PassengerId => 乘客ID
# Survived    => 是否幸存
# Pclass      => 乘客等级(1/2/3等舱位)
# Name        => 乘客姓名
# Sex         => 性别
# Age         => 年龄
# SibSp       => 堂兄弟/妹个数
# Parch       => 父母与小孩个数
# Ticket      => 船票信息
# Fare        => 票价
# Cabin       => 客舱
# Embarked    => 登船港口

# %%
#写入代码
df = adata.rename(index=str, columns={'PassengerId':'乘客ID', 'Survived':'是否幸存', 'Pclass':'乘客等级', 'Name':'乘客姓名', 'Sex':'性别', 'Age':'年龄', 'SibSp':'堂兄妹个数', 'Parch':'父母与小孩个数', 'Ticket':'船票信息', 'Fare':'票价', 'Cabin':'客舱', 'Embarked':'登船港口'})
df = df.drop(df.columns[0], axis=1)
print(df)
# Out:
#      乘客ID  是否幸存  乘客等级                                               乘客姓名  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          性别    年龄  堂兄妹个数  父母与小孩个数              船票信息       票价    客舱 登船港口    a
# ...

# %% [markdown]
# 【思考】所谓将表头改为中文其中一个思路是：将英文列名表头替换成中文。还有其他的方法吗？

# %% [markdown]
# ### 1.2 初步观察
# 导入数据后，你可能要对数据的整体结构和样例进行概览，比如说，数据大小、有多少列，各列都是什么格式的，是否包含null等

# %% [markdown]
# #### 1.2.1 任务一：查看数据的基本信息

# %%
#写入代码
df.describe() # 查看数据统计信息
df.shape # 查看数据多少行和列
df.info() # 查看没列，总共有891行，其中年龄、客舱和登船港口中有null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 13 columns):
# 乘客ID       891 non-null int64
# 是否幸存       891 non-null int64
# 乘客等级       891 non-null int64
# 乘客姓名       891 non-null object
# 性别         891 non-null object
# 年龄         714 non-null float64
# 堂兄妹个数      891 non-null int64
# 父母与小孩个数    891 non-null int64
# 船票信息       891 non-null object
# 票价         891 non-null float64
# 客舱         204 non-null object
# 登船港口       889 non-null object
# a          891 non-null int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 97.5+ KB

# %% [markdown]
# 【提示】有多个函数可以这样做，你可以做一下总结

# %% [markdown]
# #### 1.2.2 任务二：观察表格前10行的数据和后15行的数据

# %%
#写入代码
df.head(10) # 查看数据前10行
# Out:
#    乘客ID  是否幸存  乘客等级                                               乘客姓名  \
# 0     1     0     3                            Braund, Mr. Owen Harris
# 1     2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     3     1     3                             Heikkinen, Miss. Laina
# 3     4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4     5     0     3                           Allen, Mr. William Henry
# 5     6     0     3                                   Moran, Mr. James
# 6     7     0     1                            McCarthy, Mr. Timothy J
# 7     8     0     3                     Palsson, Master. Gosta Leonard
# 8     9     1     3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9    10     1     2                Nasser, Mrs. Nicholas (Adele Achem)
#
#        性别    年龄  堂兄妹个数  父母与小孩个数              船票信息       票价    客舱 登船港口    a
# 0    male  22.0      1        0         A/5 21171   7.2500   NaN    S  100
# ...

# %%
#写入代码
df.tail(15) # 查看数据后15行
# Out:
#      乘客ID  是否幸存  乘客等级                                           乘客姓名      性别  \
# 876   877     0     3                  Gustafsson, Mr. Alfred Ossian    male
# 877   878     0     3                           Petroff, Mr. Nedelio    male
# 878   879     0     3                             Laleff, Mr. Kristo    male
# 879   880     1     1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 880   881     1     2   Shelley, Mrs. William (Imanita Parrish Hall)  female
# 881   882     0     3                             Markun, Mr. Johann    male
# 882   883     0     3                   Dahlberg, Miss. Gerda Ulrika  female
# 883   884     0     2                  Banfield, Mr. Frederick James    male
# 884   885     0     3                         Sutehall, Mr. Henry Jr    male
# 885   886     0     3           Rice, Mrs. William (Margaret Norton)  female
# 886   887     0     2                          Montvila, Rev. Juozas    male
# ...

# %% [markdown]
# #### 1.2.4 任务三：判断数据是否为空，为空的地方返回True，其余地方返回False

# %%
#写入代码
df_TF = df.isna()
print(df_TF)
# Out:
#       乘客ID   是否幸存   乘客等级   乘客姓名     性别     年龄  堂兄妹个数  父母与小孩个数   船票信息     票价  \
# 0    False  False  False  False  False  False  False    False  False  False
# 1    False  False  False  False  False  False  False    False  False  False
# 2    False  False  False  False  False  False  False    False  False  False
# 3    False  False  False  False  False  False  False    False  False  False
# 4    False  False  False  False  False  False  False    False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...      ...    ...    ...
# 886  False  False  False  False  False  False  False    False  False  False
# 887  False  False  False  False  False  False  False    False  False  False
# 888  False  False  False  False  False   True  False    False  False  False
# 889  False  False  False  False  False  False  False    False  False  False
# 890  False  False  False  False  False  False  False    False  False  False
#
#         客舱   登船港口      a
# 0     True  False  False
# ...

# %% [markdown]
# 【总结】上面的操作都是数据分析中对于数据本身的观察

# %% [markdown]
# 【思考】对于一个数据，还可以从哪些方面来观察？找找答案，这个将对下面的数据分析有很大的帮助

# %% [markdown]
# ### 1.3 保存数据

# %% [markdown]
# #### 1.3.1 任务一：将你加载并做出改变的数据，在工作目录下保存为一个新文件train_chinese.csv

# %%
#写入代码
# 注意：不同的操作系统保存下来可能会有乱码。大家可以加入`encoding='GBK' 或者 ’encoding = ’uft-8‘‘`
df.to_csv('train_chinese.csv', encoding='utf_8_sig')

# %% [markdown]
# 【总结】数据的加载以及入门，接下来就要接触数据本身的运算，我们将主要掌握numpy和pandas在工作和项目场景的运用。
